# %% [markdown]
# # Phase 14 — Embeddings & vector store (ChromaDB)
#
# **Input:** `../data/cleaned/conversations_for_rag.csv` (`text_for_rag`, `conversation_id`, `position`, …).
#
# **Output:** persisted Chroma collection (path under e.g. `../data/chroma/` or project default) for RAG retrieval in the backend (Phase 20+).

# %%
from pathlib import Path

import pandas as pd

src = Path("../data/cleaned/conversations_for_rag.csv")
assert src.exists(), f"Missing {src} — run notebooks/08_eda_and_cleaning.ipynb save cell first."

df = pd.read_csv(src, low_memory=False)
print(df.shape)
print(df.head(2).to_string())

# TODO: batch embed `text_for_rag`, upsert into Chroma with ids = tweet_id (or composite key)
# import chromadb
# ...
