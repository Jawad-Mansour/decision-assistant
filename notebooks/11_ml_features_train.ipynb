# %% [markdown]
# # Phases 11–13 — Features, split, train
#
# | Phase | Task |
# |-------|------|
# | 11 | Feature engineering (length, `!`, `?`, caps ratio, sentiment, …) |
# | 12 | Train / validation / test split (60 / 20 / 20) |
# | 13 | Train & pick best model → e.g. `../models/priority_classifier.pkl` |
#
# **Input:** labeled questions from Phase 10.
#
# **Output:** model artifact + optional feature matrix parquet/csv for evaluation.

# %%
from pathlib import Path

import pandas as pd

RANDOM_STATE = 42

labeled = Path("../data/cleaned/questions_labeled.csv")
assert labeled.exists(), f"Missing {labeled} — complete Phase 10 first."

df = pd.read_csv(labeled, low_memory=False)
print(df.shape, list(df.columns))

# TODO Phase 11: build X (features) from question text + metadata
# TODO Phase 12: train_val_test_split(..., stratify=...)
# TODO Phase 13: fit models, select best, joblib.dump(...)
